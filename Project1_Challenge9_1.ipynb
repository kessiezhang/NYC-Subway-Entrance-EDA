# %%
import pandas as pd
from datetime import datetime
import csv
import urllib.request
import codecs

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 3)

# %%
# Copy desired dates from website: http://web.mta.info/developers/turnstile.html
raw_dates_txt = """
Saturday, January 12, 2019
Saturday, January 05, 2019
Saturday, December 29, 2018
Saturday, December 22, 2018"""

# %% [markdown]
# ### Creates 'turnstile_data' file and saves to project folder

# %%
date_obj_lst = [datetime.strftime(datetime.strptime(line, '%A, %B %d, %Y'), '%y%m%d') for line in raw_dates_txt.split('\n') if line]
    
turnstile_url = ['http://web.mta.info/developers/data/nyct/turnstile/turnstile_' + date + '.txt' for date in date_obj_lst]

with open('turnstile_data', 'w') as outfile:
    writer = csv.writer(outfile, delimiter=',')
    ftpstream = urllib.request.urlopen(turnstile_url[0])
    csvfile = csv.reader(codecs.iterdecode(ftpstream, 'utf-8'))
    for line in csvfile:
        writer.writerow(line)    
    for url in turnstile_url[1:]:
        ftpstream = urllib.request.urlopen(url)
        csvfile = csv.reader(codecs.iterdecode(ftpstream, 'utf-8'))
        firstline = True
        for line in csvfile:
            if firstline:    #skip first line
                firstline = False
                continue
            writer.writerow(line)

# %%
with open('turnstile_data') as input:
    Jan05 = pd.read_csv(input)

# %%
Jan05
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/05/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/05/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/05/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/05/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/05/2019
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/05/2019
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2019
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2019
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2019
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2019
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2019
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 804810  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/20/2018
# 804811  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/20/2018
# 804812  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/20/2018
# 804813  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/20/2018
# 804814  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/20/2018
# 804815  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/20/2018
# 804816  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/21/2018
# 804817  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/21/2018
# 804818  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/21/2018
# 804819  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/21/2018
# 804820  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/21/2018
# 804821  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/21/2018
#
#             TIME     DESC  ENTRIES  \
# 0       03:00:00  REGULAR  6897012
# 1       07:00:00  REGULAR  6897023
# 2       11:00:00  REGULAR  6897083
# 3       15:00:00  REGULAR  6897262
# 4       19:00:00  REGULAR  6897572
# 5       23:00:00  REGULAR  6897740
# 6       03:00:00  REGULAR  6897782
# 7       07:00:00  REGULAR  6897793
# 8       11:00:00  REGULAR  6897854
# 9       15:00:00  REGULAR  6898015
# 10      19:00:00  REGULAR  6898260
# 11      23:00:00  REGULAR  6898382
# ...          ...      ...      ...
# 804810  00:00:00  REGULAR     5554
# 804811  04:00:00  REGULAR     5554
# 804812  08:00:00  REGULAR     5554
# 804813  12:00:00  REGULAR     5554
# 804814  16:00:00  REGULAR     5554
# 804815  20:00:00  REGULAR     5554
# 804816  00:00:00  REGULAR     5554
# 804817  04:00:00  REGULAR     5554
# 804818  08:00:00  REGULAR     5554
# 804819  12:00:00  REGULAR     5554
# 804820  16:00:00  REGULAR     5554
# 804821  20:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2338472
# 1                                                 2338487
# 2                                                 2338565
# 3                                                 2338624
# 4                                                 2338679
# 5                                                 2338703
# 6                                                 2338707
# 7                                                 2338714
# 8                                                 2338762
# 9                                                 2338818
# 10                                                2338870
# 11                                                2338887
# ...                                                   ...
# 804810                                                366
# 804811                                                366
# 804812                                                366
# 804813                                                366
# 804814                                                366
# 804815                                                366
# 804816                                                366
# 804817                                                366
# 804818                                                366
# 804819                                                366
# 804820                                                366
# 804821                                                366
#
# [804822 rows x 11 columns]

# %%
Jan05.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
Jan05.isnull().sum() # equivalent to: Jan05.isna().sum()
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
Jan05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804822 entries, 0 to 804821
# Data columns (total 11 columns):
# C/A                                                                     804822 non-null object
# UNIT                                                                    804822 non-null object
# SCP                                                                     804822 non-null object
# STATION                                                                 804822 non-null object
# LINENAME                                                                804822 non-null object
# DIVISION                                                                804822 non-null object
# DATE                                                                    804822 non-null object
# TIME                                                                    804822 non-null object
# DESC                                                                    804822 non-null object
# ENTRIES                                                                 804822 non-null int64
# EXITS                                                                   804822 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 67.5+ MB

# %%
Jan05.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6897012
# 1  REGULAR  6897023
# 2  REGULAR  6897083
# 3  REGULAR  6897262
# 4  REGULAR  6897572
#
#    EXITS
# 0                                            2338472
# 1                                            2338487
# 2                                            2338565
# 3                                            2338624
# 4                                            2338679

# %%
Jan05.columns = [col.strip() for col in Jan05.columns]
Jan05.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
Jan05['ENTRIES DIFF'] = Jan05.groupby('STATION')['ENTRIES'].diff()

# %%
Jan05['ENTRIES DIFF'] = Jan05.groupby('STATION')['ENTRIES'].diff()
Jan05['EXITS DIFF'] = Jan05.groupby('STATION')['EXITS'].diff()

# %%
Jan05[Jan05['ENTRIES DIFF'] < 0].count()
#since we have 2% of the dirty data, we can drop the data
# Out:
# C/A             16123
# UNIT            16123
# SCP             16123
# STATION         16123
# LINENAME        16123
# DIVISION        16123
# DATE            16123
# TIME            16123
# DESC            16123
# ENTRIES         16123
# EXITS           16123
# ENTRIES DIFF    16123
# EXITS DIFF      16123
# dtype: int64

# %%
Jan05[Jan05['EXITS DIFF'] < 0].count()
# Out:
# C/A             14955
# UNIT            14955
# SCP             14955
# STATION         14955
# LINENAME        14955
# DIVISION        14955
# DATE            14955
# TIME            14955
# DESC            14955
# ENTRIES         14955
# EXITS           14955
# ENTRIES DIFF    14955
# EXITS DIFF      14955
# dtype: int64

# %%
Jan05[(Jan05['ENTRIES DIFF'] < 0) & (Jan05['EXITS DIFF'] < 0)].count()
# Out:
# C/A             10359
# UNIT            10359
# SCP             10359
# STATION         10359
# LINENAME        10359
# DIVISION        10359
# DATE            10359
# TIME            10359
# DESC            10359
# ENTRIES         10359
# EXITS           10359
# ENTRIES DIFF    10359
# EXITS DIFF      10359
# dtype: int64

# %%
Jan05[(Jan05['ENTRIES DIFF'] < 0) | (Jan05['EXITS DIFF'] < 0)].count()
# Out:
# C/A             20719
# UNIT            20719
# SCP             20719
# STATION         20719
# LINENAME        20719
# DIVISION        20719
# DATE            20719
# TIME            20719
# DESC            20719
# ENTRIES         20719
# EXITS           20719
# ENTRIES DIFF    20719
# EXITS DIFF      20719
# dtype: int64

# %%
Jan05['ENTRIES DIFF'].isna().sum()
# Out:
# 377

# %%
Jan05['EXITS DIFF'].isna().sum()
# Out:
# 377

# %%
#dropping the negative difference and nan
Jan05=Jan05.drop(Jan05[Jan05['ENTRIES DIFF'] < 0].index)
Jan05=Jan05.drop(Jan05[Jan05['EXITS DIFF'] < 0].index)
Jan05=Jan05.dropna()

# %%
Jan05.isna().sum()
# Out:
# C/A             0
# UNIT            0
# SCP             0
# STATION         0
# LINENAME        0
# DIVISION        0
# DATE            0
# TIME            0
# DESC            0
# ENTRIES         0
# EXITS           0
# ENTRIES DIFF    0
# EXITS DIFF      0
# dtype: int64

# %%
#station name cleansing
#the strip() removes characters from both left and right based on the argument
Jan05['STATION']=[name.strip() for name in Jan05.STATION]

# %% [markdown]
# ### Challenge 9
# **Over multiple weeks, sum total ridership for each station and sort them, so you can find out the stations with the highest traffic during the time you investigate**

# %%
Jan05['year_month'] = pd.to_datetime(Jan05['DATE']).dt.to_period('M')

# %%
Jan05.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  19:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  23:00:00
#
#       DESC  ENTRIES    EXITS  ENTRIES DIFF  EXITS DIFF year_month
# 1  REGULAR  6897023  2338487          11.0        15.0    2019-01
# 2  REGULAR  6897083  2338565          60.0        78.0    2019-01
# 3  REGULAR  6897262  2338624         179.0        59.0    2019-01
# 4  REGULAR  6897572  2338679         310.0        55.0    2019-01
# 5  REGULAR  6897740  2338703         168.0        24.0    2019-01

# %%
Jan05['year_month_station'] = Jan05['year_month'].map(str) + ' ' + Jan05['STATION']

# %%
Jan05.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  19:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2019  23:00:00
#
#       DESC  ENTRIES    EXITS  ENTRIES DIFF  EXITS DIFF year_month  \
# 1  REGULAR  6897023  2338487          11.0        15.0    2019-01
# 2  REGULAR  6897083  2338565          60.0        78.0    2019-01
# 3  REGULAR  6897262  2338624         179.0        59.0    2019-01
# 4  REGULAR  6897572  2338679         310.0        55.0    2019-01
# 5  REGULAR  6897740  2338703         168.0        24.0    2019-01
#
#   year_month_station
# 1      2019-01 59 ST
# 2      2019-01 59 ST
# 3      2019-01 59 ST
# 4      2019-01 59 ST
# 5      2019-01 59 ST

# %%
Jan05.groupby('year_month_station')['ENTRIES DIFF'].sum()
# Out:
# year_month_station
# 2018-12 1 AV               3.940e+09
# 2018-12 103 ST             1.875e+08
# 2018-12 103 ST-CORONA      6.658e+07
# 2018-12 104 ST             8.389e+09
# 2018-12 110 ST             2.966e+07
# 2018-12 111 ST             2.048e+08
# 2018-12 116 ST             4.485e+09
# 2018-12 116 ST-COLUMBIA    3.473e+09
# 2018-12 121 ST             5.838e+09
# 2018-12 125 ST             1.085e+10
# 2018-12 135 ST             2.795e+08
# 2018-12 137 ST CITY COL    5.649e+08
#                              ...
# 2019-01 WEST FARMS SQ      4.287e+08
# 2019-01 WESTCHESTER SQ     7.163e+06
# 2019-01 WHITEHALL S-FRY    1.394e+08
# 2019-01 WHITLOCK AV        3.980e+06
# 2019-01 WILSON AV          7.731e+05
# 2019-01 WINTHROP ST        1.625e+07
# 2019-01 WOODHAVEN BLVD     3.812e+07
# 2019-01 WOODLAWN           5.970e+06
# 2019-01 WORLD TRADE CTR    1.587e+09
# 2019-01 WTC-CORTLANDT      7.309e+08
# 2019-01 YORK ST            1.019e+05
# 2019-01 ZEREGA AV          8.418e+05
# Name: ENTRIES DIFF, Length: 754, dtype: float64

# %%
plt.figure(figsize=[200,100])
plt.plot(df_station_total)

# %%
df_station_total = Jan05[Jan05['ENTRIES DIFF'].sum()]
df_station_total

# %%
ym_station = [name for name in Jan05['year_month_station'].unique()]

# %%
df_ym_station_sort= (Jan05.set_index(ym_station)
                              .sort_index())
